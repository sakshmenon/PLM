# %%
# Script to parse the UniProt report on variants of a given protein

# %%
import json
import csv

# %%
def extract_variant_info(json_file):
    with open(json_file, 'r') as file:
        data = json.load(file)

    variants_info = []

    for feature in data.get('features', []):
        if feature.get('type') == 'VARIANT':
            if feature.get('consequenceType') == 'missense':
                try:
                    genomicLocation = feature.get('genomicLocation')[0]
            
                    if '>' in genomicLocation:
                        values = (genomicLocation[15:]).split('>')
                        mutated_n = values[1]
                        n_position = values[0][:-1]
                        original_n = values[0][-1]
                        
                        nucleotide_change = f"{original_n}>{mutated_n}"

                        try:
                            chromosome = feature.get('cytogeneticBand')[:2]
                
                            aa_position = feature.get('begin')
                            original_aa = feature.get('wildType')
                            mutated_aa = feature.get('mutatedType')
                            aa_change = f"{original_aa}{aa_position}{mutated_aa}"
                            phenotypes = []

                            for association in feature.get('association', []):
                                phenotype_name = association.get('name')
                                if phenotype_name:
                                    phenotypes.append(phenotype_name)
                            
                            variant_info = {
                                'Chromosome': chromosome,
                                'NTPosition': n_position,
                                'NTChange': nucleotide_change,
                                'AAPosition': aa_position,
                                'AAChange': aa_change,
                                'Phenotype': ', '.join(phenotypes)
                            }
                            variants_info.append(variant_info)
                        except:
                            continue

                except TypeError:
                    continue

    return variants_info

# %%
def save_to_csv(data, csv_file):
    with open(csv_file, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['Chromosome', 'NTPosition', 'NTChange', 'AAPosition', 'AAChange', 'Phenotype'])
        writer.writeheader()
        for row in data:
            writer.writerow({
                'Chromosome': row['Chromosome'],
                'NTPosition': row['NTPosition'],
                'NTChange': row['NTChange'], 
                'AAPosition':row['AAPosition'], 
                'AAChange':row['AAChange'], 
                'Phenotype': row['Phenotype']
            })

# %%
# Usage
json_file = 'O00555-variants.json'
variant_info_list = extract_variant_info(json_file)

# Printing the extracted information
for variant in variant_info_list:
    print(f"Chromosome: {variant['Chromosome']}, NTPosition: {variant['NTPosition']}, NTChange: {variant['NTChange']}, AAPosition:{variant['AAPosition']}, AAChange:{variant['Phenotype']}, Phenotype: {variant['Phenotype']}")
# Out:
# Chromosome: 19, NTPosition: 13506221, NTChange: C>A, AAPosition:2, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506220, NTChange: G>A, AAPosition:2, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506218, NTChange: G>A, AAPosition:3, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506218, NTChange: G>C, AAPosition:3, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506211, NTChange: C>A, AAPosition:5, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506201, NTChange: C>G, AAPosition:8, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506199, NTChange: G>A, AAPosition:9, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506200, NTChange: G>A, AAPosition:9, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506197, NTChange: C>A, AAPosition:10, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506196, NTChange: G>A, AAPosition:10, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13506193, NTChange: C>T, AAPosition:11, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506190, NTChange: T>C, AAPosition:12, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506190, NTChange: T>A, AAPosition:12, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506191, NTChange: A>G, AAPosition:12, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506187, NTChange: C>G, AAPosition:13, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506187, NTChange: C>T, AAPosition:13, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506188, NTChange: C>T, AAPosition:13, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506184, NTChange: C>T, AAPosition:14, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506185, NTChange: C>T, AAPosition:14, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506175, NTChange: G>C, AAPosition:17, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506175, NTChange: G>A, AAPosition:17, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506176, NTChange: A>G, AAPosition:17, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506173, NTChange: C>G, AAPosition:18, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506173, NTChange: C>A, AAPosition:18, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506170, NTChange: C>T, AAPosition:19, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506169, NTChange: G>A, AAPosition:19, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506163, NTChange: G>A, AAPosition:21, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13506160, NTChange: C>G, AAPosition:22, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506160, NTChange: C>T, AAPosition:22, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506157, NTChange: A>C, AAPosition:23, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506151, NTChange: A>C, AAPosition:25, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506146, NTChange: T>C, AAPosition:27, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506145, NTChange: C>A, AAPosition:27, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506145, NTChange: C>G, AAPosition:27, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506137, NTChange: C>T, AAPosition:30, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506137, NTChange: C>A, AAPosition:30, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506128, NTChange: C>A, AAPosition:33, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506124, NTChange: C>T, AAPosition:34, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506125, NTChange: C>G, AAPosition:34, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506121, NTChange: C>T, AAPosition:35, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506116, NTChange: G>C, AAPosition:37, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506115, NTChange: C>T, AAPosition:37, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506116, NTChange: G>A, AAPosition:37, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506109, NTChange: C>T, AAPosition:39, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506107, NTChange: C>G, AAPosition:40, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506107, NTChange: C>A, AAPosition:40, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506103, NTChange: T>A, AAPosition:41, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506101, NTChange: G>A, AAPosition:42, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13506098, NTChange: C>T, AAPosition:43, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506094, NTChange: G>C, AAPosition:44, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506095, NTChange: C>T, AAPosition:44, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13506084, NTChange: C>T, AAPosition:47, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506071, NTChange: T>C, AAPosition:52, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506056, NTChange: G>A, AAPosition:57, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506050, NTChange: T>C, AAPosition:59, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13506034, NTChange: G>T, AAPosition:64, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506034, NTChange: G>A, AAPosition:64, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506035, NTChange: G>A, AAPosition:64, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13506028, NTChange: G>C, AAPosition:66, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506026, NTChange: C>T, AAPosition:67, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506022, NTChange: C>T, AAPosition:68, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13506016, NTChange: T>C, AAPosition:70, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13506013, NTChange: C>T, AAPosition:71, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506011, NTChange: G>A, AAPosition:72, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506007, NTChange: G>A, AAPosition:73, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506005, NTChange: C>G, AAPosition:74, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13506000, NTChange: G>C, AAPosition:75, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13505999, NTChange: G>A, AAPosition:76, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505990, NTChange: A>C, AAPosition:79, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13505989, NTChange: A>T, AAPosition:79, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505975, NTChange: C>G, AAPosition:84, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505971, NTChange: T>A, AAPosition:85, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505971, NTChange: T>C, AAPosition:85, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13505969, NTChange: C>A, AAPosition:86, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505966, NTChange: C>T, AAPosition:87, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505959, NTChange: T>C, AAPosition:89, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505947, NTChange: T>A, AAPosition:93, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13505932, NTChange: G>A, AAPosition:98, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13505933, NTChange: G>A, AAPosition:98, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455210, NTChange: G>A, AAPosition:99, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455204, NTChange: T>G, AAPosition:101, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455205, NTChange: C>T, AAPosition:101, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455205, NTChange: C>G, AAPosition:101, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Developmental and epileptic encephalopathy 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Developmental and epileptic encephalopathy 42 (DEE42)
# Chromosome: 19, NTPosition: 13455197, NTChange: C>T, AAPosition:103, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455198, NTChange: A>G, AAPosition:103, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455190, NTChange: C>T, AAPosition:106, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455189, NTChange: G>A, AAPosition:106, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455182, NTChange: G>C, AAPosition:108, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455184, NTChange: T>C, AAPosition:108, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455177, NTChange: G>A, AAPosition:110, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455169, NTChange: T>C, AAPosition:113, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455160, NTChange: C>A, AAPosition:116, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455160, NTChange: C>T, AAPosition:116, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455159, NTChange: G>A, AAPosition:116, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455152, NTChange: C>G, AAPosition:118, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455141, NTChange: G>A, AAPosition:122, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455139, NTChange: C>T, AAPosition:123, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455138, NTChange: T>A, AAPosition:123, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455134, NTChange: A>C, AAPosition:124, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455130, NTChange: T>C, AAPosition:126, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455127, NTChange: T>C, AAPosition:127, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13455123, NTChange: G>A, AAPosition:128, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455124, NTChange: G>A, AAPosition:128, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13455111, NTChange: C>T, AAPosition:132, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13453006, NTChange: C>T, AAPosition:137, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452997, NTChange: A>G, AAPosition:140, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452993, NTChange: A>G, AAPosition:141, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452991, NTChange: C>T, AAPosition:142, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452987, NTChange: A>T, AAPosition:143, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452982, NTChange: A>C, AAPosition:145, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452976, NTChange: C>T, AAPosition:147, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452961, NTChange: T>C, AAPosition:152, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452957, NTChange: A>G, AAPosition:153, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452958, NTChange: T>C, AAPosition:153, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452938, NTChange: G>T, AAPosition:159, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452927, NTChange: G>A, AAPosition:163, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452914, NTChange: A>C, AAPosition:167, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452915, NTChange: T>C, AAPosition:167, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452913, NTChange: C>T, AAPosition:168, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452907, NTChange: T>C, AAPosition:170, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452904, NTChange: C>T, AAPosition:171, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452896, NTChange: G>T, AAPosition:173, AAChange:Spinocerebellar ataxia type 6 (SCA6), Phenotype: Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13452889, NTChange: C>G, AAPosition:176, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452889, NTChange: C>T, AAPosition:176, AAChange:CACNA1A-Related Disorder, Phenotype: CACNA1A-Related Disorder
# Chromosome: 19, NTPosition: 13452885, NTChange: A>C, AAPosition:177, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452883, NTChange: G>C, AAPosition:178, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13452879, NTChange: G>A, AAPosition:179, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13452877, NTChange: C>A, AAPosition:180, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371772, NTChange: C>T, AAPosition:183, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371771, NTChange: G>A, AAPosition:183, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371765, NTChange: A>G, AAPosition:185, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371759, NTChange: G>A, AAPosition:187, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371757, NTChange: C>G, AAPosition:188, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371747, NTChange: A>G, AAPosition:191, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371744, NTChange: C>T, AAPosition:192, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Familial hemiplegic migraine, Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Familial hemiplegic migraine, Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1)
# Chromosome: 19, NTPosition: 13371745, NTChange: G>A, AAPosition:192, AAChange:Cerebellar ataxia, Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spastic paraparesis, Phenotype: Cerebellar ataxia, Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spastic paraparesis
# Chromosome: 19, NTPosition: 13371741, NTChange: G>A, AAPosition:193, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371735, NTChange: C>T, AAPosition:195, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1)
# Chromosome: 19, NTPosition: 13371730, NTChange: C>T, AAPosition:197, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371727, NTChange: G>A, AAPosition:198, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371727, NTChange: G>C, AAPosition:198, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371726, NTChange: C>T, AAPosition:198, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13371717, NTChange: C>T, AAPosition:201, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13371718, NTChange: G>A, AAPosition:201, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371714, NTChange: G>A, AAPosition:202, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371712, NTChange: G>C, AAPosition:203, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371708, NTChange: T>C, AAPosition:204, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371703, NTChange: C>T, AAPosition:206, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371696, NTChange: C>G, AAPosition:208, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13371696, NTChange: C>T, AAPosition:208, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13371697, NTChange: C>T, AAPosition:208, AAChange:Inborn genetic diseases, Phenotype: Inborn genetic diseases
# Chromosome: 19, NTPosition: 13371688, NTChange: T>C, AAPosition:211, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365469, NTChange: C>T, AAPosition:211, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365457, NTChange: A>G, AAPosition:215, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365458, NTChange: C>T, AAPosition:215, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365455, NTChange: G>T, AAPosition:216, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365448, NTChange: G>A, AAPosition:218, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Familial hemiplegic migraine, Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Familial hemiplegic migraine, Migraine, familial hemiplegic, 1, Migraine, familial hemiplegic, 1 (FHM1)
# Chromosome: 19, NTPosition: 13365449, NTChange: A>G, AAPosition:218, AAChange:Developmental and epileptic encephalopathy, 52 (DEE52), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 52 (DEE52), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13365448, NTChange: G>C, AAPosition:218, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365446, NTChange: T>A, AAPosition:219, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365446, NTChange: T>C, AAPosition:219, AAChange:Disorder of sexual differentiation, Phenotype: Disorder of sexual differentiation
# Chromosome: 19, NTPosition: 13365441, NTChange: C>T, AAPosition:220, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365443, NTChange: T>C, AAPosition:220, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365427, NTChange: G>C, AAPosition:225, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13365421, NTChange: A>C, AAPosition:227, AAChange:Spinocerebellar ataxia type 6 (SCA6), Phenotype: Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13365416, NTChange: T>C, AAPosition:229, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365413, NTChange: C>G, AAPosition:230, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365413, NTChange: C>T, AAPosition:230, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365412, NTChange: C>A, AAPosition:230, AAChange:Migraine, familial hemiplegic, 1, Phenotype: Migraine, familial hemiplegic, 1
# Chromosome: 19, NTPosition: 13365409, NTChange: A>C, AAPosition:231, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1
# Chromosome: 19, NTPosition: 13365403, NTChange: A>G, AAPosition:233, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365401, NTChange: A>G, AAPosition:234, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365392, NTChange: T>C, AAPosition:237, AAChange:Global developmental delay (DD), Spinocerebellar ataxia type 6 (SCA6), Phenotype: Global developmental delay (DD), Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13365385, NTChange: A>G, AAPosition:239, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365386, NTChange: T>C, AAPosition:239, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365358, NTChange: T>C, AAPosition:248, AAChange:Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13365356, NTChange: T>C, AAPosition:249, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13365352, NTChange: C>T, AAPosition:250, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365350, NTChange: T>C, AAPosition:251, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13365344, NTChange: G>A, AAPosition:253, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13365341, NTChange: T>C, AAPosition:254, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365340, NTChange: G>T, AAPosition:254, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365334, NTChange: C>A, AAPosition:256, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365335, NTChange: A>G, AAPosition:256, AAChange:Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13365328, NTChange: T>G, AAPosition:258, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13365322, NTChange: C>T, AAPosition:260, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359799, NTChange: T>A, AAPosition:262, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359796, NTChange: T>A, AAPosition:263, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359790, NTChange: T>G, AAPosition:265, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359790, NTChange: T>C, AAPosition:265, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359787, NTChange: C>T, AAPosition:266, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359788, NTChange: C>T, AAPosition:266, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13359784, NTChange: T>C, AAPosition:267, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359785, NTChange: C>T, AAPosition:267, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359778, NTChange: G>A, AAPosition:269, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359770, NTChange: A>G, AAPosition:272, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359769, NTChange: C>T, AAPosition:272, AAChange:CACNA1A-Related Disorder, Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: CACNA1A-Related Disorder, Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359763, NTChange: G>A, AAPosition:274, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359757, NTChange: T>C, AAPosition:276, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359752, NTChange: C>A, AAPosition:278, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359752, NTChange: C>T, AAPosition:278, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359751, NTChange: G>A, AAPosition:278, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359749, NTChange: G>A, AAPosition:279, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Developmental and epileptic encephalopathy, 52 (DEE52), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Developmental and epileptic encephalopathy, 52 (DEE52), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13359748, NTChange: C>T, AAPosition:279, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359745, NTChange: G>A, AAPosition:280, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359746, NTChange: T>G, AAPosition:280, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359739, NTChange: G>A, AAPosition:282, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359740, NTChange: G>T, AAPosition:282, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359736, NTChange: T>C, AAPosition:283, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13359733, NTChange: C>A, AAPosition:284, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359731, NTChange: T>G, AAPosition:285, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359727, NTChange: T>C, AAPosition:286, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359724, NTChange: C>T, AAPosition:287, AAChange:Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13359718, NTChange: G>T, AAPosition:289, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359719, NTChange: G>A, AAPosition:289, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359708, NTChange: T>G, AAPosition:292, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359710, NTChange: C>T, AAPosition:292, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359707, NTChange: C>T, AAPosition:293, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia 6 (SCA6), Spinocerebellar ataxia type 6 (SCA6), Episodic ataxia 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia 6 (SCA6), Spinocerebellar ataxia type 6 (SCA6), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13359703, NTChange: G>A, AAPosition:294, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359695, NTChange: C>T, AAPosition:297, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359683, NTChange: A>G, AAPosition:301, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359679, NTChange: T>C, AAPosition:302, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13359680, NTChange: C>G, AAPosition:302, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359680, NTChange: C>T, AAPosition:302, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13359677, NTChange: T>C, AAPosition:303, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359665, NTChange: C>A, AAPosition:307, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359664, NTChange: G>A, AAPosition:307, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359662, NTChange: C>G, AAPosition:308, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359662, NTChange: C>T, AAPosition:308, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359659, NTChange: G>T, AAPosition:309, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359655, NTChange: G>A, AAPosition:310, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13359607, NTChange: T>C, AAPosition:326, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335903, NTChange: C>G, AAPosition:329, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13335903, NTChange: C>T, AAPosition:329, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13335893, NTChange: C>T, AAPosition:332, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335889, NTChange: G>T, AAPosition:333, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335888, NTChange: T>C, AAPosition:334, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335887, NTChange: G>A, AAPosition:334, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335867, NTChange: T>C, AAPosition:341, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335864, NTChange: G>A, AAPosition:342, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335861, NTChange: G>A, AAPosition:343, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335858, NTChange: T>G, AAPosition:344, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335853, NTChange: G>C, AAPosition:345, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1
# Chromosome: 19, NTPosition: 13335855, NTChange: T>C, AAPosition:345, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335849, NTChange: C>T, AAPosition:347, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13335829, NTChange: G>T, AAPosition:353, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Inborn genetic diseases, Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Inborn genetic diseases, Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13335828, NTChange: G>A, AAPosition:354, AAChange:Migraine, familial hemiplegic, 1, Phenotype: Migraine, familial hemiplegic, 1
# Chromosome: 19, NTPosition: 13335827, NTChange: A>T, AAPosition:354, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335828, NTChange: G>C, AAPosition:354, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335825, NTChange: C>G, AAPosition:355, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335821, NTChange: A>G, AAPosition:356, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13335818, NTChange: C>T, AAPosition:357, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13335816, NTChange: C>T, AAPosition:358, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334474, NTChange: C>T, AAPosition:368, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334471, NTChange: G>A, AAPosition:369, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334458, NTChange: C>T, AAPosition:373, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334459, NTChange: G>A, AAPosition:373, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334455, NTChange: C>T, AAPosition:374, AAChange:Inborn genetic diseases, Intellectual disability, Phenotype: Inborn genetic diseases, Intellectual disability
# Chromosome: 19, NTPosition: 13334434, NTChange: C>G, AAPosition:381, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334434, NTChange: C>T, AAPosition:381, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334435, NTChange: G>A, AAPosition:381, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Inborn genetic diseases
# Chromosome: 19, NTPosition: 13334425, NTChange: T>C, AAPosition:384, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334416, NTChange: C>T, AAPosition:387, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334411, NTChange: G>A, AAPosition:389, AAChange:Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2), Episodic ataxia 2 (EA2)
# Chromosome: 19, NTPosition: 13334410, NTChange: A>G, AAPosition:389, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1
# Chromosome: 19, NTPosition: 13334408, NTChange: T>C, AAPosition:390, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334406, NTChange: A>T, AAPosition:390, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13334407, NTChange: T>C, AAPosition:390, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334405, NTChange: C>T, AAPosition:391, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13334402, NTChange: A>C, AAPosition:392, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334394, NTChange: C>G, AAPosition:394, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13334389, NTChange: A>G, AAPosition:396, AAChange:Intellectual disability, Phenotype: Intellectual disability
# Chromosome: 19, NTPosition: 13334387, NTChange: A>C, AAPosition:397, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13332925, NTChange: T>A, AAPosition:400, AAChange:Episodic ataxia type 2 (EA2), Idiopathic hemiconvulsion-hemiplegia syndrome, Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Episodic ataxia type 2 (EA2), Idiopathic hemiconvulsion-hemiplegia syndrome, Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13332915, NTChange: G>C, AAPosition:403, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13332911, NTChange: C>T, AAPosition:405, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Spinocerebellar ataxia 6 (SCA6)
# Chromosome: 19, NTPosition: 13332910, NTChange: G>A, AAPosition:405, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13332908, NTChange: C>T, AAPosition:406, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13332904, NTChange: T>G, AAPosition:407, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13332904, NTChange: T>C, AAPosition:407, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13332900, NTChange: T>G, AAPosition:408, AAChange:, Phenotype:
# ...
# Chromosome: 19, NTPosition: 13207591, NTChange: A>G, AAPosition:2415, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207586, NTChange: G>C, AAPosition:2416, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207588, NTChange: C>T, AAPosition:2416, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207584, NTChange: T>C, AAPosition:2417, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207585, NTChange: C>T, AAPosition:2417, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207584, NTChange: T>A, AAPosition:2417, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207581, NTChange: G>C, AAPosition:2418, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207581, NTChange: G>A, AAPosition:2418, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207579, NTChange: C>T, AAPosition:2419, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207573, NTChange: G>C, AAPosition:2421, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207572, NTChange: G>A, AAPosition:2421, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13207565, NTChange: G>C, AAPosition:2423, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207564, NTChange: C>T, AAPosition:2424, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207560, NTChange: C>T, AAPosition:2425, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207560, NTChange: C>A, AAPosition:2425, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207557, NTChange: C>T, AAPosition:2426, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207558, NTChange: C>T, AAPosition:2426, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207555, NTChange: C>T, AAPosition:2427, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207551, NTChange: T>G, AAPosition:2428, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207550, NTChange: C>A, AAPosition:2428, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207545, NTChange: A>G, AAPosition:2430, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207543, NTChange: C>G, AAPosition:2431, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207543, NTChange: C>T, AAPosition:2431, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207542, NTChange: G>A, AAPosition:2431, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207539, NTChange: C>T, AAPosition:2432, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207540, NTChange: C>T, AAPosition:2432, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207537, NTChange: C>T, AAPosition:2433, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207534, NTChange: A>G, AAPosition:2434, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207531, NTChange: C>T, AAPosition:2435, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207528, NTChange: C>T, AAPosition:2436, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207527, NTChange: G>A, AAPosition:2436, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207524, NTChange: G>T, AAPosition:2437, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207522, NTChange: G>A, AAPosition:2438, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207522, NTChange: G>T, AAPosition:2438, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207518, NTChange: G>T, AAPosition:2439, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207518, NTChange: G>A, AAPosition:2439, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13207519, NTChange: G>T, AAPosition:2439, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207515, NTChange: A>T, AAPosition:2440, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207516, NTChange: C>T, AAPosition:2440, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207513, NTChange: G>C, AAPosition:2441, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207512, NTChange: C>G, AAPosition:2441, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207512, NTChange: C>T, AAPosition:2441, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207507, NTChange: C>G, AAPosition:2443, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207507, NTChange: C>T, AAPosition:2443, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207506, NTChange: G>A, AAPosition:2443, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13207503, NTChange: G>A, AAPosition:2444, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207500, NTChange: G>A, AAPosition:2445, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207501, NTChange: A>G, AAPosition:2445, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207497, NTChange: C>G, AAPosition:2446, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207495, NTChange: C>T, AAPosition:2447, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207489, NTChange: C>T, AAPosition:2449, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207486, NTChange: G>A, AAPosition:2450, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13207485, NTChange: C>T, AAPosition:2450, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207486, NTChange: G>T, AAPosition:2450, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207482, NTChange: G>A, AAPosition:2451, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207483, NTChange: A>G, AAPosition:2451, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207477, NTChange: T>C, AAPosition:2453, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207476, NTChange: C>T, AAPosition:2453, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207470, NTChange: G>C, AAPosition:2455, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207468, NTChange: G>C, AAPosition:2456, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207467, NTChange: C>A, AAPosition:2456, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207467, NTChange: C>G, AAPosition:2456, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207468, NTChange: G>A, AAPosition:2456, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207465, NTChange: C>A, AAPosition:2457, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207465, NTChange: C>T, AAPosition:2457, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207464, NTChange: G>A, AAPosition:2457, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207462, NTChange: A>C, AAPosition:2458, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207461, NTChange: G>A, AAPosition:2458, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207455, NTChange: G>A, AAPosition:2460, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207456, NTChange: G>A, AAPosition:2460, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207453, NTChange: C>G, AAPosition:2461, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207453, NTChange: C>A, AAPosition:2461, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207453, NTChange: C>T, AAPosition:2461, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207452, NTChange: G>A, AAPosition:2461, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207446, NTChange: G>C, AAPosition:2463, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207447, NTChange: C>A, AAPosition:2463, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207446, NTChange: G>A, AAPosition:2463, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207443, NTChange: G>A, AAPosition:2464, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207438, NTChange: A>G, AAPosition:2466, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207435, NTChange: G>C, AAPosition:2467, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207434, NTChange: C>G, AAPosition:2467, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13207434, NTChange: C>T, AAPosition:2467, AAChange:Episodic ataxia type 2 (EA2), Phenotype: Episodic ataxia type 2 (EA2)
# Chromosome: 19, NTPosition: 13207435, NTChange: G>A, AAPosition:2467, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207430, NTChange: G>C, AAPosition:2468, AAChange:CACNA1A-related disorders, Phenotype: CACNA1A-related disorders
# Chromosome: 19, NTPosition: 13207429, NTChange: C>A, AAPosition:2469, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207429, NTChange: C>T, AAPosition:2469, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207425, NTChange: C>A, AAPosition:2470, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207425, NTChange: C>T, AAPosition:2470, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207426, NTChange: G>A, AAPosition:2470, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207422, NTChange: C>T, AAPosition:2471, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207420, NTChange: G>A, AAPosition:2472, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207410, NTChange: C>G, AAPosition:2475, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207411, NTChange: C>A, AAPosition:2475, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207410, NTChange: C>T, AAPosition:2475, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207411, NTChange: C>T, AAPosition:2475, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207410, NTChange: C>A, AAPosition:2475, AAChange:Inborn genetic diseases, Phenotype: Inborn genetic diseases
# Chromosome: 19, NTPosition: 13207407, NTChange: T>C, AAPosition:2476, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207408, NTChange: A>C, AAPosition:2476, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207408, NTChange: A>G, AAPosition:2476, AAChange:Inborn genetic diseases, Phenotype: Inborn genetic diseases
# Chromosome: 19, NTPosition: 13207408, NTChange: A>T, AAPosition:2476, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207405, NTChange: A>G, AAPosition:2477, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207402, NTChange: G>C, AAPosition:2478, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207401, NTChange: G>A, AAPosition:2478, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207398, NTChange: G>C, AAPosition:2479, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207398, NTChange: G>A, AAPosition:2479, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207395, NTChange: T>G, AAPosition:2480, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207394, NTChange: G>C, AAPosition:2480, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207395, NTChange: T>C, AAPosition:2480, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207396, NTChange: G>A, AAPosition:2480, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207393, NTChange: C>T, AAPosition:2481, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42), Episodic ataxia type 2 (EA2), Migraine, familial hemiplegic, 1, Spinocerebellar ataxia type 6 (SCA6)
# Chromosome: 19, NTPosition: 13207389, NTChange: A>C, AAPosition:2482, AAChange:Developmental and epileptic encephalopathy, 42 (DEE42), Phenotype: Developmental and epileptic encephalopathy, 42 (DEE42)
# Chromosome: 19, NTPosition: 13207390, NTChange: G>C, AAPosition:2482, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207387, NTChange: C>T, AAPosition:2483, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207386, NTChange: G>A, AAPosition:2483, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207384, NTChange: T>C, AAPosition:2484, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207383, NTChange: C>T, AAPosition:2484, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207382, NTChange: C>A, AAPosition:2484, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207380, NTChange: G>A, AAPosition:2485, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207378, NTChange: G>A, AAPosition:2486, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207377, NTChange: C>T, AAPosition:2486, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207375, NTChange: C>T, AAPosition:2487, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207375, NTChange: C>A, AAPosition:2487, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207371, NTChange: G>A, AAPosition:2488, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207372, NTChange: G>A, AAPosition:2488, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207368, NTChange: C>T, AAPosition:2489, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207365, NTChange: G>C, AAPosition:2490, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207365, NTChange: G>A, AAPosition:2490, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207366, NTChange: A>G, AAPosition:2490, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207365, NTChange: G>T, AAPosition:2490, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207362, NTChange: C>T, AAPosition:2491, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207361, NTChange: C>G, AAPosition:2491, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207359, NTChange: T>C, AAPosition:2492, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207357, NTChange: C>A, AAPosition:2493, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207349, NTChange: G>C, AAPosition:2495, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207347, NTChange: T>G, AAPosition:2496, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207345, NTChange: G>C, AAPosition:2497, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207344, NTChange: G>A, AAPosition:2497, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207345, NTChange: G>A, AAPosition:2497, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207341, NTChange: T>C, AAPosition:2498, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207342, NTChange: A>G, AAPosition:2498, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207334, NTChange: C>G, AAPosition:2500, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207335, NTChange: T>C, AAPosition:2500, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207336, NTChange: C>T, AAPosition:2500, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207336, NTChange: C>G, AAPosition:2500, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207333, NTChange: T>A, AAPosition:2501, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207333, NTChange: T>C, AAPosition:2501, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207332, NTChange: C>T, AAPosition:2501, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207333, NTChange: T>G, AAPosition:2501, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207332, NTChange: C>G, AAPosition:2501, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207328, NTChange: G>C, AAPosition:2502, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207327, NTChange: C>G, AAPosition:2503, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207327, NTChange: C>T, AAPosition:2503, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207323, NTChange: T>C, AAPosition:2504, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207318, NTChange: A>T, AAPosition:2506, AAChange:, Phenotype:
# Chromosome: 19, NTPosition: 13207317, NTChange: C>T, AAPosition:2506, AAChange:, Phenotype:

# %%
# save to a file
csv_file = 'O00555-variants.csv'
save_to_csv(variant_info_list, csv_file)
